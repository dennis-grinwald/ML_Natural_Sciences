# %% [markdown]
# # Hyperspectral Remote Sensing Scenes Anlysis

# %% [markdown]
# In this homework you are asked to analyse the images collected from saltelites with hyperspectral cameras from a particular earth region.

# %% [markdown]
# ## 1. Data preparation (20P)
#
# * Download the _Indian Pines_ dataset from the
# __[Hyperspectral Data](http://www.ehu.eus/ccwintco/index.php/Hyperspectral_Remote_Sensing_Scenes)__  website in order to perform the classification. - DONE
#
# * Split data into __train__ and __test__ set in proportions 80% to 20% - DONE

# %%
import numpy as np
import copy
import scipy.io
from sklearn.mixture import GaussianMixture
from sklearn.cluster import SpectralClustering
from sklearn.metrics import accuracy_score
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.base import BaseEstimator, ClassifierMixin
import matplotlib.pyplot as plt
import spectral

# %% [markdown]
# ### Explore Indian Pines data
# This scene was gathered by AVIRIS sensor over the Indian Pines test site in North-western Indiana and consists of 145*145 pixels and 224 spectral reflectance bands in the wavelength range 0.4–2.5 10^(-6) meters.

# %%
# load the data
raw_data = scipy.io.loadmat('Indian_pines_corrected.mat')['indian_pines_corrected']
raw_ground_truth = scipy.io.loadmat('Indian_pines_gt.mat')['indian_pines_gt']

data = raw_data.reshape(-1,200,order='C')
ground_truth=raw_ground_truth.reshape(-1,order='C')

# shapes
print(f"Data shape: {raw_data.shape}")
print(f"Labels shape: {raw_ground_truth.shape}")
print(f"Max. pixel value: {raw_data.max(2).shape}")

# plot some sample bands
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1,4,figsize=(20,10))
i = np.random.randint(raw_data.shape[2])
ax1.imshow(raw_data[:,:,i])
ax1.set_title(f"Band: {i}")

i = np.random.randint(raw_data.shape[2])
ax2.imshow(raw_data[:,:,i])
ax2.set_title(f"Band: {i}")

i = np.random.randint(raw_data.shape[2])
ax3.imshow(raw_data[:,:,i])
ax3.set_title(f"Band: {i}")

i = np.random.randint(raw_data.shape[2])
ax4.imshow(raw_data[:,:,i])
ax4.set_title(f"Band: {i}")

plt.show()

plt.imshow(raw_ground_truth)
plt.title("Ground Truth of pine data_set")
# Out:
# Data shape: (145, 145, 200)
# Labels shape: (145, 145)
# Max. pixel value: (145, 145)
# Text(0.5,1,'Ground Truth of pine data_set')

# %% [markdown]
# ### Split the data

# %%
data_no_zero = raw_data.reshape(-1,200,order='C')[np.argwhere(ground_truth).squeeze()]

ground_truth_no_zero_indices = np.argwhere(ground_truth)
ground_truth_no_zero = ground_truth[ground_truth_no_zero_indices]

training_data = data_no_zero[:int(.8*data_no_zero.shape[0])]
training_labels = ground_truth_no_zero[:int(.8*ground_truth_no_zero.shape[0])]

test_data = data_no_zero[int(.8*data_no_zero.shape[0]):]
test_labels = ground_truth_no_zero[int(.8*ground_truth_no_zero.shape[0]):]

print(f"Length of training set: {training_data.shape[0]}")
print(f"Length of test set: {test_data.shape[0]}")
# Out:
# Length of training set: 8199
# Length of test set: 2050

# %% [markdown]
# ## 2. Data Classification
# In this section we'll apply different algorithms from the **_sklearn_** package in order to do find the best classification error.

# %% [markdown]
# ### 2.1 Semi-supervised classification (40 P)

# %% [markdown]
# ### Question: Use whole data set ?
#
# * Draw 10% datapoints from each class to be used as semi-supervised labels and fix them. - DONE
#
# * Perform the _Mixture of Gaussians_ (sklearn.mixture.GaussianMixture) clustering with full covariance matrices on the input space with the true number of classes. - DONE
#
# * Perform the _Spectral Clustering_ (sklearn.cluster.SpectralClustering) on the feature space with the RBF kernel for building the affinity matrix with the true number of classes. - DONE
#
# * Assign labels for each data point within a class using semi-supervised labels i.e. as maximum occurence within the class and compute the accuracy (sklearn.metrics.accuracy_score).  - DONE
#
# * Use the accuracy metric in order to make a _scorer_ (sklearn.metrics.make_scorer) and perform cross-validation parameter tuning with the grid search engine (_GridSearchCV_ class) for both models. - DONE

# %% [markdown]
# ### Sample 10% of each label class and fix them

# %%
# get distinct labels
distinct_labels = np.unique(ground_truth_no_zero)

# creates dictionary with indices of labeled class samples(10% of total class samples) from each class
# key: class label, value: list of indices of corresponding class samples(10%)
labeled_data_dict = dict()

# creates dictionary with indices of unlabeled class samples(90% of total class samples) from each class
# key: class label, value: list of indices of corresponding class samples(90%)
unlabeled_data_dict = dict()

# Get 10% of each class. Efficient loop, since we only iterate over indices
for label in distinct_labels:
    shuffled_indices = np.random.permutation(np.where(ground_truth==label)[0])
    
    labeled_data_dict[label] = shuffled_indices[:int(.1*len(shuffled_indices))]
    unlabeled_data_dict[label] = shuffled_indices[int(.1*len(shuffled_indices)):]

# build inv labeled_data_indices dict
# key: data-sample index, value: assigned label
inv_labeled_data_dict = dict()
for k,v in labeled_data_dict.items():
    for v2 in v:
        inv_labeled_data_dict[v2] = k

# labeled training data indices
labeled_data_indices = np.concatenate(list(labeled_data_dict.values()))
# unlabeled training data indices
unlabeled_data_indices = np.concatenate(list(unlabeled_data_dict.values()))
        
# fixed labeled dataset
labeled_data = data[labeled_data_indices]
labeled_data_labels = ground_truth[labeled_data_indices]
 
# fixed unlabeled data
unlabeled_data = data[unlabeled_data_indices]
unlabeled_data_labels = ground_truth[unlabeled_data_indices]

# %%
print(f"Length of training data: {training_data.shape[0]}")
print(f"Length of labeled data set: {labeled_data.shape[0]}")
print(f"Length of unlabeled data set: {unlabeled_data.shape[0]}")
print(f"Fraction of training data: {round(labeled_data.shape[0]*100 / data_no_zero.shape[0])} %")
# Out:
# Length of training data: 8199
# Length of labeled data set: 1018
# Length of unlabeled data set: 9231
# Fraction of training data: 10 %

# %% [markdown]
# ### Gaussian Mixture Classifier
# The classifier does the following:
# First it clusters all points. Then it looks into the computed clusters and counts the maximum occurence of a labels from the labeled data points that appear in the cluster. The cluster then gets assigned this max. occuring label.
# When predicting, we only predict the labels of the unlabeled data points and use these predictions for the scoring function later.

# %%
class GMMClassifier(BaseEstimator, ClassifierMixin):

    def __init__(self, cov_type='full', max_iter=100, n_init=1):
        self.cov_type = cov_type
        self.max_iter = max_iter
        self.n_init = n_init

        self.gmm = GaussianMixture(
            n_components=len(distinct_labels),
            covariance_type=self.cov_type,
            max_iter=self.max_iter,
            n_init=self.n_init
        )

    def fit(self, X):
        self.gmm.fit(X)

        return self

    def predict(self, X=unlabeled_data, y=inv_labeled_data_dict):
        """Assign label to each cluster, according to max occ. of labeled points within those clusters
        Parameters:
            - data
            - labeled data
        Returns:
            - (re-)labeled gauss cluster predictions of unlabeled samples
        """
        clustered_data_labels = self.gmm.predict(X)

        # assign labels to each cluster based on max occurence of label of
        # labeled data samples within that cluster
        for cluster_id in np.unique(clustered_data_labels):
            cluster_indices = np.argwhere(clustered_data_labels == cluster_id)
            tmp_labels = []

            for index in cluster_indices:
                # get real data label if exists - only take labels from semi supervised data
                try:
                    tmp_label = y[index[0]]
                    tmp_labels.append(tmp_label)
                except:
                    continue

            if tmp_labels != []:
                # get most frequent label
                tmp_counts = np.bincount(tmp_labels)
                max_label = np.argmax(tmp_counts)

                # assign all cluster points to the max label
                clustered_data_labels[cluster_indices] = max_label
        y = clustered_data_labels

        return y

    def score(self, X, y_true=unlabeled_data_labels):
        # predictions for unlabeled data samples
        predictions = self.predict()
        
        return accuracy_score(predictions, y_true)

# %%
classifier_gmm = GMMClassifier()
classifier_gmm = classifier_gmm.fit(data_no_zero)
gmm_cluster_predictions = classifier_gmm.predict(unlabeled_data)

# %%
# Compute accuracy score
gauss_acc = accuracy_score(gmm_cluster_predictions, unlabeled_data_labels)
print(f"Accuracy using Gaussian Mixture Clustering: {100*gauss_acc}%")
# Out:
# Accuracy using Gaussian Mixture Clustering: 11.515545444697215%

# %% [markdown]
# ### Fine Tuning Hyper Parameters with Cross Validation

# %%
params = {
    'cov_type': ['full', 'tied', 'diag', 'spherical'],
    'max_iter': [100,10,1],
    'n_init': [100,10,1]
}

grid = GridSearchCV(
            estimator=GMMClassifier(),
            param_grid=params,
            cv=3
)

grid = grid.fit(data_no_zero)

# Print best results
print(f"Best achieved val accuracy: {grid.best_score_}")
print(f"Best hyperparams: {grid.best_params_}")

gmm_cluster_predictions = grid.predict(unlabeled_data)
print(f"Accuracy on unlabeled data with best hyperparam. setup: {accuracy_score(gmm_cluster_predictions, unlabeled_data_labels)*100}%")
# Out:
# Best achieved val accuracy: 0.15296066520183027
# Best hyperparams: {'cov_type': 'diag', 'max_iter': 10, 'n_init': 1}
# Accuracy on unlabeled data with best hyperparam. setup: 17.6145596360091%

# %% [markdown]
# ### Evaluation:
# As we can see cross-validation with hyperparameter search finds an optimal setup, where a final best accuracy of 17.61% is achieved.

# %% [markdown]
# ### Spectral clustering Classification
# The classifier does the following:
# First it clusters all points. Then it looks into the computed clusters and counts the maximum occurence of a labels from the labeled data points that appear in the cluster. The cluster then gets assigned this max. occuring label.
# When predicting, we only predict the labels of the unlabeled data points and use these predictions for the scoring function later.

# %%
class SpectralClassifier(BaseEstimator, ClassifierMixin):
    
    def __init__(self, affinity='rbf', gamma=1.0, assign_labels="kmeans", full_labels=ground_truth):    
        self.full_labels=full_labels
        self.affinity=affinity 
        self.gamma=gamma
        self.assign_labels=assign_labels
        self.spec_clusterer = SpectralClustering(
            n_clusters=len(distinct_labels),
            affinity=self.affinity,
            gamma=self.gamma,
            assign_labels=self.assign_labels
        )
        
    def fit(self, X, y):
        self.train_labels = y
        self.spec_clustering=self.spec_clusterer.fit(X)
        
        return self
        
    def predict(self, y=inv_labeled_data_dict):
        
        """Assign label to each cluster, according to max occ. of labeled points within those clusters
        Parameters:
            - data
            - labeled data
        Returns:
            - (re-)labeled gauss cluster predictions of unlabeled samples
        """
        
        clustered_data_labels = self.spec_clustering.labels_
        
        # assign labels to each cluster based on max occurence of label of 
        # labeled data samples within that cluster
        for cluster_id in np.unique(clustered_data_labels):
            cluster_indices = np.argwhere(clustered_data_labels == cluster_id)
            tmp_labels = []
    
            for index in cluster_indices:
                # get real data label if exists - only take labels from semi supervised data
                try:
                    tmp_label = y[index[0]]
                    tmp_labels.append(tmp_label)
                except:
                    continue
    
            if tmp_labels != []:
                # get most frequent label
                tmp_counts = np.bincount(tmp_labels)
                max_label = np.argmax(tmp_counts)
    
                # assign all cluster points to the max label
                clustered_data_labels[cluster_indices] = max_label
            
        y = clustered_data_labels
        
        return y
    
    def score(self, X=None, y=None):
        predictions = self.predict()
        y_true=self.train_labels

        return accuracy_score(predictions, y_true)

# %%
classifier_spectral = SpectralClassifier()
classifier_spectral = classifier_spectral.fit(data_no_zero, ground_truth_no_zero)
spec_cluster_predictions = classifier_spectral.predict()

# Compute accuracy score
spec_acc = accuracy_score(spec_cluster_predictions[np.where(unlabeled_data_indices==ground_truth_no_zero_indices)[1]], ground_truth[unlabeled_data_indices])
print(f"Accuracy using Spectral Clustering Classification: {100*spec_acc}%")
# Out:
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# Accuracy using Spectral Clustering Classification: 21.438630700899143%

# %% [markdown]
# ### Fine Tuning Hyper Parameters with Cross Validation

# %%
params = {
    'gamma': [1000,100,10,1,0.1,0.01],
    'assign_labels': ['kmeans', 'discretize']
}

grid = GridSearchCV(
            estimator=SpectralClassifier(),
            param_grid=params,
            cv=3
)

grid = grid.fit(data, ground_truth)
# Out:
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/manifold/spectral_embedding_.py:237: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"

# %%
# Print best results
print(f"Best achieved val accuracy: {grid.best_score_*100}%")
print(f"Best hyperparams: {grid.best_params_}")
# Out:
# Best achieved val accuracy: 11.498360094093648%
# Best hyperparams: {'assign_labels': 'kmeans', 'gamma': 100}

# %%
spec_predictions = grid.predict(inv_labeled_data_dict)
# Compute accuracy score
spec_acc = accuracy_score(spec_cluster_predictions[np.where(unlabeled_data_indices==ground_truth_no_zero_indices)[1]], ground_truth[unlabeled_data_indices])
print(f"Accuracy using Spectral Clustering Classification: {100*spec_acc}%")
# Out:
# Accuracy using Spectral Clustering Classification: 21.438630700899143%

# %% [markdown]
# ### Evaluation
# As we can see cross-validation with hyperparameter search finds an optimal setup, where a final best accuracy of 21.44% is achieved.

# %% [markdown]
# ### 2.2 Supervised classification (20 P)

# %% [markdown]
# * Run multiclass Support Vector Machine classification in order to find labels for the unlabeled pixels. - DONE
#
# * Compute the overall pixels-wise error for the data _test_ set. - DONE
#
# * Use this metric in order to make a _scorer_ (_sklearn.metrics.make_scorer_) and perform cross-validation parameter tuning with the grid search engine (_GridSearchCV_ class). - DONE

# %% [markdown]
# ### SVM multiclass classification

# %%
svm = SVC(kernel='linear')
svm.fit(training_data, training_labels)
# Out:
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
test_set_predictions = svm.predict(test_data)
svm_test_acc = accuracy_score(test_set_predictions, test_labels)
print(f"SVM test classification accuracy: {round(svm_test_acc*100,6)}%")
# Out:
# SVM test classification accuracy: 61.512195%

# %% [markdown]
# ### Fine Tuning Hyper Parameters with Cross Validation

# %%
# Define hyper-params to optimize
params = [
    {'C': [10, 1, 0.1], 'kernel': ['linear']},
    {'C': [10, 1, 0.1], 'kernel': ['rbf'], 'gamma': ['scale', 'auto', 10 , 1, 0.1]}
]

# Define scorer
def test_scorer(test_data, test_labels):
    score = accuracy_score(test_data, test_labels)
    return score
    
accuracy_scorer = make_scorer(test_scorer, greater_is_better=True)

svm_grid = GridSearchCV(
    estimator=SVC(), 
    param_grid=params, 
    scoring=accuracy_scorer
)

svm_grid = svm_grid.fit(training_data, training_labels)
# Out:
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/grinwald/env/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print(f"Best achieved val accuracy: {svm_grid.best_score_*100}%")
print(f"Best hyperparams: {svm_grid.best_params_}")

test_predictions_svm = svm_grid.predict(test_data)
test_acc = accuracy_score(test_predictions_svm, test_labels)
print(f"Final Test accuracy after Grid Search: {test_acc*100}%")
# Out:
# Best achieved val accuracy: 69.63044273691914%
# Best hyperparams: {'C': 1, 'kernel': 'linear'}
# Final Test accuracy after Grid Search: 61.512195121951216%

# %%
train_predictions_svm = svm_grid.predict(training_data)

# %% [markdown]
# ## 3. Data Visualization (20 P)

# %% [markdown]
# * Visualize your classification results as the __covermap__ (_spectral.imshow_ ) using different colors for each class and compare it visually with the __normal__ image representation. - TBD
#
# * Does your __covermap__ respresent the analysed data properly or not ? Compute the overall pixels-wise classification error - TBD

# %%
spec_predictions[np.where(unlabeled_data_indices==ground_truth_no_zero_indices)[1]].shape
# Out:
# (9231,)

# %%
# Original
spectral.imshow(classes=raw_ground_truth, title="Ground Truth")

# GMM
gmm_preds = copy.deepcopy(ground_truth)
gmm_preds[unlabeled_data_indices] = gmm_cluster_predictions
spectral.imshow(classes=gmm_preds.reshape(145,145,order='C'), title="GMM Clustering")

# Spectral Clustering
spec_preds = copy.deepcopy(ground_truth)
spec_preds[unlabeled_data_indices] = spec_predictions[np.where(unlabeled_data_indices==ground_truth_no_zero_indices)[1]]
spectral.imshow(classes=spec_preds.reshape(145,145,order='C'), title="Spectral Clustering")

# SVM
svm_preds = copy.deepcopy(ground_truth)
svm_preds[ground_truth_no_zero_indices.squeeze()] = np.append(train_predictions_svm, test_set_predictions)
spectral.imshow(classes=svm_preds.reshape(145,145,order='C'), title='SVM prediction')
# Out:
# ImageView object:
#   Interpolation       :  <default>

# %% [markdown]
# ### Explanations:
# As we can see, the SVM classifier has learnt very well to predict the classes of the test and trainings pixels. Though it cannot be compared to the performances of the clustering algorihtms, since it uses much more data for training(80%), wheras the clustering classifiers only use 10% of labeled data points.
#
# When comparing the clustering classifiers it might look like the GMM actually performs better, since it predicts more patched-together fields of pixels. The problem though is that it often makes wrong predictions about the true label of the pixels and thus als classifies all surrounding pixels wrong, which results in a bad prediction performance(17.6% at it's best).
# The spectral clustering classifier on the other hand seems to predict the pixels in a must harder to follow fashion, since it doesn't necessarily assigns the same label to surrounding pixels, compared to the GMM, but rather predicts smaller patches of pixels, and it does so often right, when comparing it to the ground truth. Also it seems to have a bias towards one of the classes, which cover much of the data space(light green), thus it often predicts whole patches with this label since the probability is high, that this actually is the right label. One way to tackle this would be to assign weightings on the classes, according to the relative amount of training datapoints, that belong to that class.

# %% [markdown]
# ## 4. Optional Task (+50 P)
#
# * Define your own Deep Neural Network Architecture in order to defeat the best model you've already found from the previous tasks. - DONE
#
# * Show that your resuls are better or similar to the results from the previous models empirically as well as visually. - Done

# %%
import time
import copy
import itertools
import sys

import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import LambdaLR

# %% [markdown]
# # Trial: Use Conv. Neural Network(pretrained)
# ### max. SVM test acc. to beat ~ 61.51%

# %%
class CustomDataset(Dataset):
    
    def __init__(self, data, labels):
        self.data = torch.FloatTensor(data)
        self.labels = torch.LongTensor(labels)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]
    
class NNClassifier(nn.Module):
    
    def __init__(self, inp_size):
        super(NNClassifier, self).__init__()
        self.fc1 = nn.Linear(200, 100)
        self.fc2 = nn.Linear(100, len(np.unique(ground_truth)))
    
    def forward(self, x):
        
        output = F.relu(self.fc1(x))
        output = self.fc2(output)
        
        return output

# %% [markdown]
# ### Convert dataset into torch-compatible objects

# %%
torch_training_data = CustomDataset(
    training_data.astype(float), 
    training_labels
)

torch_test_data = CustomDataset(
    test_data.astype(float), 
    test_labels
)

# %%
def train(parameters):
    # define torch data loaders
    batch_size = parameters[0]
    learning_rate = parameters[1]
    weigh_decay = parameters[2]

    train_loader = torch.utils.data.DataLoader(
        torch_training_data, 
        batch_size=batch_size,
        shuffle=True
    )
    
    test_loader = torch.utils.data.DataLoader(
        torch_test_data, 
        batch_size=batch_size,
        shuffle=True
    )
    
    # Define Model
    inp_size = batch_size * 200
    epochs = 20
    best_model = None
    best_val_acc = 0.0

    model = NNClassifier(inp_size)

    # define optimizer
    optimizer = torch.optim.Adam(
        params=model.parameters(),
        lr=0.001,
        weight_decay=0.01
    )

    #lambda1 = lambda epoch: 0.995 ** epoch
    #scheduler = LambdaLR(optimizer, lr_lambda=lambda1)

    # define loss
    criterion = torch.nn.CrossEntropyLoss()

    for e, epoch in enumerate(range(epochs)):
    
        #scheduler.step()
    
        # evaluation loop
        with torch.no_grad():
            total = 0.0
            correct_predicted = 0.0
        
            for i, (data, labels) in enumerate(test_loader):
        
                optimizer.zero_grad()
                out = model(data)
                predictions = out.max(1)[1]
            
                correct_predicted += (predictions == labels.squeeze()).sum()
                total += labels.shape[0]
        
            val_acc = (correct_predicted.item() / total)
            #print(f"\nEPOCH: {e}")
            #print(f"\nValidation accuracy: {val_acc*100}%")
        
            if val_acc > best_val_acc:
                best_val_acc = val_acc
                best_model = copy.deepcopy(model)
        
        # training loop
        total_loss = 0.0
        for i, (data, labels) in enumerate(train_loader):
        
            model.train()
        
            optimizer.zero_grad()
            out = model(data)
        
            try:
                loss = criterion(out, labels.squeeze())
                loss.backward()
                optimizer.step()
                total_loss += loss.item()
            except:
                continue
        #print(f"Train loss: {total_loss} ")
    
    return best_model, best_val_acc

# %%
learning_rates = [0.1, 0.05, 0.01, 0.005, 0.001, 0.0001]
batch_sizes = [100, 50, 25, 12]
weight_decays = [0.01, 0.005, 0.001, 0.0005,]
param_list = list(itertools.product(*[batch_sizes, learning_rates, weight_decays]))

# %%
import time
final_acc = 0.0
final_model = None
final_params = None

for params in param_list:
    
    tmp_best_model, tmp_best_val_acc = train(params)
    
    print(f"Best accuracy after training with params:")
    print(f"batch_size: {params[0]}\nlearning_rate: {params[1]}\nweight_decay: {params[2]}: \ntest_acc: {tmp_best_val_acc*100}%")
    if tmp_best_val_acc > final_acc:
        print(f"\nFOUND NEW TOP ACC:")
        print(f"Test Accuracy: {tmp_best_val_acc*100}%\n")
        final_acc = tmp_best_val_acc
        final_model = copy.deepcopy(tmp_best_model)
        final_params = params

test_loader = torch.utils.data.DataLoader(
        torch_test_data, 
        batch_size=10,
        shuffle=True
)

# Evaluate final Test accuracy
pred_labels_nn = []
with torch.no_grad():
    total = 0.0
    correct_predicted = 0.0
        
    for i, (data, labels) in enumerate(test_loader):
        
        out = final_model(data)
        predictions = out.max(1)[1]
        pred_labels_nn.append(predictions.detach().numpy())
        
        correct_predicted += (predictions == labels.squeeze()).sum()
        total += len(labels)
        
    test_acc = (correct_predicted.item() / total)
    print(f"Final test accuracy: {test_acc*100}%")
# Out:
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.1
# weight_decay: 0.01:
# test_acc: 52.926829268292686%
#
# FOUND NEW TOP ACC:
# Test Accuracy: 52.926829268292686%
#
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.1
# weight_decay: 0.005:
# test_acc: 54.926829268292686%
#
# FOUND NEW TOP ACC:
# Test Accuracy: 54.926829268292686%
#
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.1
# weight_decay: 0.001:
# test_acc: 51.463414634146346%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.1
# weight_decay: 0.0005:
# test_acc: 66.8780487804878%
#
# FOUND NEW TOP ACC:
# Test Accuracy: 66.8780487804878%
#
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.05
# weight_decay: 0.01:
# test_acc: 51.609756097560975%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.05
# weight_decay: 0.005:
# test_acc: 60.731707317073166%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.05
# weight_decay: 0.001:
# test_acc: 62.390243902439025%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.05
# weight_decay: 0.0005:
# test_acc: 47.3170731707317%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.01
# weight_decay: 0.01:
# test_acc: 59.756097560975604%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.01
# weight_decay: 0.005:
# test_acc: 51.31707317073171%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.01
# weight_decay: 0.001:
# test_acc: 55.21951219512196%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.01
# weight_decay: 0.0005:
# test_acc: 52.73170731707317%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.005
# weight_decay: 0.01:
# test_acc: 55.5609756097561%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.005
# weight_decay: 0.005:
# test_acc: 58.195121951219505%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.005
# weight_decay: 0.001:
# test_acc: 57.512195121951216%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.005
# weight_decay: 0.0005:
# test_acc: 55.90243902439025%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.001
# weight_decay: 0.01:
# test_acc: 53.707317073170735%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.001
# weight_decay: 0.005:
# test_acc: 60.4390243902439%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.001
# weight_decay: 0.001:
# test_acc: 57.99999999999999%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.001
# weight_decay: 0.0005:
# test_acc: 54.78048780487805%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.0001
# weight_decay: 0.01:
# test_acc: 50.6829268292683%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.0001
# weight_decay: 0.005:
# test_acc: 60.0%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.0001
# weight_decay: 0.001:
# test_acc: 58.14634146341463%
# Best accuracy after training with params:
# batch_size: 100
# learning_rate: 0.0001
# weight_decay: 0.0005:
# test_acc: 48.829268292682926%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.1
# weight_decay: 0.01:
# test_acc: 56.975609756097555%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.1
# weight_decay: 0.005:
# test_acc: 49.170731707317074%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.1
# weight_decay: 0.001:
# test_acc: 53.268292682926834%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.1
# weight_decay: 0.0005:
# test_acc: 43.75609756097561%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.05
# weight_decay: 0.01:
# test_acc: 23.219512195121954%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.05
# weight_decay: 0.005:
# test_acc: 63.46341463414634%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.05
# weight_decay: 0.001:
# test_acc: 60.048780487804876%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.05
# weight_decay: 0.0005:
# test_acc: 60.97560975609756%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.01
# weight_decay: 0.01:
# test_acc: 51.85365853658537%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.01
# weight_decay: 0.005:
# test_acc: 53.268292682926834%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.01
# weight_decay: 0.001:
# test_acc: 54.97560975609757%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.01
# weight_decay: 0.0005:
# test_acc: 48.19512195121951%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.005
# weight_decay: 0.01:
# test_acc: 66.73170731707317%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.005
# weight_decay: 0.005:
# test_acc: 49.1219512195122%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.005
# weight_decay: 0.001:
# test_acc: 41.02439024390244%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.005
# weight_decay: 0.0005:
# test_acc: 63.5609756097561%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.001
# weight_decay: 0.01:
# test_acc: 62.0%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.001
# weight_decay: 0.005:
# test_acc: 51.36585365853659%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.001
# weight_decay: 0.001:
# test_acc: 56.243902439024396%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.001
# weight_decay: 0.0005:
# test_acc: 52.4390243902439%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.0001
# weight_decay: 0.01:
# test_acc: 64.92682926829268%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.0001
# weight_decay: 0.005:
# test_acc: 53.85365853658537%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.0001
# weight_decay: 0.001:
# test_acc: 61.02439024390244%
# Best accuracy after training with params:
# batch_size: 50
# learning_rate: 0.0001
# weight_decay: 0.0005:
# test_acc: 56.8780487804878%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.1
# weight_decay: 0.01:
# test_acc: 63.65853658536585%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.1
# weight_decay: 0.005:
# test_acc: 63.26829268292683%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.1
# weight_decay: 0.001:
# test_acc: 62.048780487804876%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.1
# weight_decay: 0.0005:
# test_acc: 57.65853658536585%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.05
# weight_decay: 0.01:
# test_acc: 46.04878048780488%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.05
# weight_decay: 0.005:
# test_acc: 49.26829268292683%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.05
# weight_decay: 0.001:
# test_acc: 65.5609756097561%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.05
# weight_decay: 0.0005:
# test_acc: 61.609756097560975%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.01
# weight_decay: 0.01:
# test_acc: 34.8780487804878%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.01
# weight_decay: 0.005:
# test_acc: 33.02439024390244%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.01
# weight_decay: 0.001:
# test_acc: 54.926829268292686%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.01
# weight_decay: 0.0005:
# test_acc: 29.756097560975608%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.005
# weight_decay: 0.01:
# test_acc: 56.634146341463406%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.005
# weight_decay: 0.005:
# test_acc: 44.09756097560976%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.005
# weight_decay: 0.001:
# test_acc: 51.170731707317074%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.005
# weight_decay: 0.0005:
# test_acc: 47.170731707317074%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.001
# weight_decay: 0.01:
# test_acc: 57.3170731707317%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.001
# weight_decay: 0.005:
# test_acc: 26.682926829268293%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.001
# weight_decay: 0.001:
# test_acc: 14.926829268292682%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.001
# weight_decay: 0.0005:
# test_acc: 57.853658536585364%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.0001
# weight_decay: 0.01:
# test_acc: 13.170731707317074%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.0001
# weight_decay: 0.005:
# test_acc: 57.17073170731707%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.0001
# weight_decay: 0.001:
# test_acc: 43.90243902439025%
# Best accuracy after training with params:
# batch_size: 25
# learning_rate: 0.0001
# weight_decay: 0.0005:
# test_acc: 58.78048780487804%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.1
# weight_decay: 0.01:
# test_acc: 55.5609756097561%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.1
# weight_decay: 0.005:
# test_acc: 13.560975609756099%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.1
# weight_decay: 0.001:
# test_acc: 22.390243902439025%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.1
# weight_decay: 0.0005:
# test_acc: 13.560975609756099%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.05
# weight_decay: 0.01:
# test_acc: 13.170731707317074%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.05
# weight_decay: 0.005:
# test_acc: 13.170731707317074%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.05
# weight_decay: 0.001:
# test_acc: 13.317073170731708%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.05
# weight_decay: 0.0005:
# test_acc: 13.170731707317074%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.01
# weight_decay: 0.01:
# test_acc: 15.317073170731707%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.01
# weight_decay: 0.005:
# test_acc: 13.80487804878049%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.01
# weight_decay: 0.001:
# test_acc: 14.146341463414632%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.01
# weight_decay: 0.0005:
# test_acc: 13.219512195121952%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.005
# weight_decay: 0.01:
# test_acc: 13.170731707317074%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.005
# weight_decay: 0.005:
# test_acc: 15.609756097560975%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.005
# weight_decay: 0.001:
# test_acc: 13.170731707317074%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.005
# weight_decay: 0.0005:
# test_acc: 15.365853658536585%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.001
# weight_decay: 0.01:
# test_acc: 13.609756097560977%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.001
# weight_decay: 0.005:
# test_acc: 13.317073170731708%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.001
# weight_decay: 0.001:
# test_acc: 13.170731707317074%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.001
# weight_decay: 0.0005:
# test_acc: 13.26829268292683%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.0001
# weight_decay: 0.01:
# test_acc: 44.09756097560976%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.0001
# weight_decay: 0.005:
# test_acc: 14.341463414634145%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.0001
# weight_decay: 0.001:
# test_acc: 21.024390243902438%
# Best accuracy after training with params:
# batch_size: 12
# learning_rate: 0.0001
# weight_decay: 0.0005:
# test_acc: 13.219512195121952%
# Final test accuracy: 66.8780487804878%

# %% [markdown]
# # Empirical Solution:
# As we can see that Deep Neural Network, when performing hyperparameter optimization has learned a better representation of the data needed for classification, thus achieving a higher accuracy on the test set: 66.87% as opposed to the best SVM test performance which is: 61.51%

# %% [markdown]
# # Visual solution:

# %%
train_loader = torch.utils.data.DataLoader(
        torch_training_data, 
        batch_size=10,
        shuffle=True
    )

train_predictions_nn = []
test_predictions_nn = []
with torch.no_grad():
    train_correct_predicted = 0
    train_total = 0
    for i, (data, labels) in enumerate(train_loader):
        
        train_total += len(labels)
        out = final_model(data)
        predictions = out.max(1)[1]
        
        train_correct_predicted += (predictions == labels.squeeze()).sum()
        
        train_predictions_nn.append(predictions.numpy())
    
    print(f"Trainning accuracy: {100*train_correct_predicted/train_total}%")
        
    test_correct_predicted = 0
    test_total = 0
    for i, (data, labels) in enumerate(test_loader):
        
        test_total += len(labels)
        out = final_model(data)
        predictions = out.max(1)[1]
        
        test_correct_predicted += (predictions == labels.squeeze()).sum()
        test_predictions_nn.append(predictions.numpy())
        
    print(f"Test accuracy: {100*test_correct_predicted/test_total}%")

train_predictions_nn = np.concatenate(train_predictions_nn)
test_predictions_nn = np.concatenate(test_predictions_nn)
# Out:
# Trainning accuracy: 42%
# Test accuracy: 66%

# %%
# Ground Truth
spectral.imshow(classes=raw_ground_truth, title="Ground Truth")

# NN Predictions
nn_preds = copy.deepcopy(ground_truth)
nn_preds[ground_truth_no_zero_indices.squeeze()] = np.append(train_predictions_nn, test_predictions_nn)
spectral.imshow(classes=nn_preds.reshape(145,145,order='C'), title='Neural Network prediction')
# Out:
# ImageView object:
#   Interpolation       :  <default>

# %% [markdown]
# In contrast to the SVM reconstructed picture the Neural Network seems to have a bias towards predicting pixels as the class, that is most present in the dataset (light green) and besides of that predicts many single pixels within this green area. Just from looking at the reconstructed picture, the SVM seems to make a better job predicting the right classes. Nevertheless the Neural Network achieves the higher accuracy when predicting measuring the overall performance of the covermap.
